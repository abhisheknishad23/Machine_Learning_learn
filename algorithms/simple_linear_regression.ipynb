# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')

# %%
df.shape
# Out:
# (19, 2)

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89      3.26
# 1  5.12      1.98
# 2  7.82      3.25
# 3  7.42      3.67
# 4  6.94      3.57

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['package '])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     3.26
# 1     1.98
# 2     3.25
# 3     3.67
# 4     3.57
# 5     2.99
# 6     2.60
# 7     2.48
# 8     2.31
# 9     3.51
# 10    1.86
# 11    2.60
# 12    3.65
# 13    2.89
# 14    3.42
# 15    3.23
# 16    2.35
# 17    2.09
# 18    2.98
# Name: package , dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     cgpa
# 9   8.31
# 4   6.94
# 14  7.73
# 0   6.89

# %%
y_test
# Out:
# 9     3.51
# 4     3.57
# 14    3.42
# 0     3.26
# Name: package , dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# D:\ML Engineer\jupyter_notebook\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.47533455])

# %%
plt.scatter(df['cgpa'],df['package '])
plt.plot(X_train, lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m=lr.coef_

# %%
b=lr.intercept_

# %%
#y=mx+b
m*6.89+b
# Out:
# array([2.7722388])

# %%
m
# Out:
# array([0.49513786])

# %%
m*5.12+b
# Out:
# array([1.89584479])

# %%
b
# Out:
# np.float64(-0.6392610314300486)
